# %%
import seaborn as sns
import pandas as pd
import seaborn.objects as so

# %%
import json

# Open and read the JSON file
with open('scib_comparison_results_Loc_celltype.json', 'r') as file:
    res = json.load(file)

# %%
res = pd.DataFrame(res).T

# %%
res
# Out:
#               KMeans NMI  KMeans ARI  Silhouette label     cLISI  \
# X_FinVAE        0.788514    0.490678          0.532172  0.992394
# X_scANVI        0.699333    0.362782          0.488895  0.983950
# X_pca_combat    0.678473    0.344338          0.486467  0.985805
# X_scPoli        0.690472    0.347132          0.470595  0.981194
# X_scVI          0.697496    0.358576          0.493069  0.984876
# X_pca           0.690577    0.332511          0.492139  0.986643
#
#               Silhouette batch  Graph connectivity  Isolated labels
# X_FinVAE              0.897987            0.949773         0.462154
# X_scANVI              0.882100            0.757687         0.393968
# X_pca_combat          0.886027            0.753698         0.414789
# X_scPoli              0.802651            0.696001         0.231544
# X_scVI                0.902652            0.754540         0.453954
# X_pca                 0.905185            0.749829         0.416362

# %%
Bio_conservation = ["Isolated labels", "KMeans NMI", "KMeans ARI", "Silhouette label", "cLISI"]
Batch_correction = ["Silhouette batch","Graph connectivity"]

# %%
Bio_conservation
# Out:
# ['Isolated labels', 'KMeans NMI', 'KMeans ARI', 'Silhouette label', 'cLISI']

# %%
res = res[Bio_conservation + Batch_correction]

# %%
res['Bio conservation'] = res[Bio_conservation].mean(axis=1)
res['Batch correction'] = res[Batch_correction].mean(axis=1)
# Out:
# /tmp/ipykernel_811/1452469857.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res['Bio conservation'] = res[Bio_conservation].mean(axis=1)
# /tmp/ipykernel_811/1452469857.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res['Batch correction'] = res[Batch_correction].mean(axis=1)

# %%
res['Total'] = res[['Bio conservation', 'Batch correction']].mean(axis=1)
# Out:
# /tmp/ipykernel_811/647163913.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res['Total'] = res[['Bio conservation', 'Batch correction']].mean(axis=1)

# %%
res
# Out:
#               Isolated labels  KMeans NMI  KMeans ARI  Silhouette label  \
# X_FinVAE             0.462154    0.788514    0.490678          0.532172
# X_scANVI             0.393968    0.699333    0.362782          0.488895
# X_pca_combat         0.414789    0.678473    0.344338          0.486467
# X_scPoli             0.231544    0.690472    0.347132          0.470595
# X_scVI               0.453954    0.697496    0.358576          0.493069
# X_pca                0.416362    0.690577    0.332511          0.492139
#
#                  cLISI  Silhouette batch  Graph connectivity  \
# X_FinVAE      0.992394          0.897987            0.949773
# X_scANVI      0.983950          0.882100            0.757687
# X_pca_combat  0.985805          0.886027            0.753698
# X_scPoli      0.981194          0.802651            0.696001
# X_scVI        0.984876          0.902652            0.754540
# X_pca         0.986643          0.905185            0.749829
#
# ...

# %%
metrics = ["Bio conservation"] * len(Bio_conservation) + ["Batch correction"] * len(Batch_correction) + ['Aggregate score']*3

# %%
res
# Out:
#               Isolated labels  KMeans NMI  KMeans ARI  Silhouette label  \
# X_FinVAE             0.462154    0.788514    0.490678          0.532172
# X_scANVI             0.393968    0.699333    0.362782          0.488895
# X_pca_combat         0.414789    0.678473    0.344338          0.486467
# X_scPoli             0.231544    0.690472    0.347132          0.470595
# X_scVI               0.453954    0.697496    0.358576          0.493069
# X_pca                0.416362    0.690577    0.332511          0.492139
#
#                  cLISI  Silhouette batch  Graph connectivity  \
# X_FinVAE      0.992394          0.897987            0.949773
# X_scANVI      0.983950          0.882100            0.757687
# X_pca_combat  0.985805          0.886027            0.753698
# X_scPoli      0.981194          0.802651            0.696001
# X_scVI        0.984876          0.902652            0.754540
# X_pca         0.986643          0.905185            0.749829
#
# ...

# %%
res.loc['Metric type'] = metrics
# Out:
# /tmp/ipykernel_811/110910762.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc['Metric type'] = metrics

# %%
res
# Out:
#                Isolated labels        KMeans NMI        KMeans ARI  \
# X_FinVAE              0.462154          0.788514          0.490678
# X_scANVI              0.393968          0.699333          0.362782
# X_pca_combat          0.414789          0.678473          0.344338
# X_scPoli              0.231544          0.690472          0.347132
# X_scVI                0.453954          0.697496          0.358576
# X_pca                 0.416362          0.690577          0.332511
# Metric type   Bio conservation  Bio conservation  Bio conservation
#
#               Silhouette label             cLISI  Silhouette batch  \
# X_FinVAE              0.532172          0.992394          0.897987
# X_scANVI              0.488895           0.98395            0.8821
# X_pca_combat          0.486467          0.985805          0.886027
# X_scPoli              0.470595          0.981194          0.802651
# X_scVI                0.493069          0.984876          0.902652
# ...

# %%
res.to_csv('scib_results_lung5loc_pool_celltype.csv')
