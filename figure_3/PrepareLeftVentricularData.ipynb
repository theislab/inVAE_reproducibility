# %% [markdown]
# # Aims
# - Read in the 2 diseased heart objects and the atlas object (subset to just LV data)
# - Ensure raw counts are in .X
# - Ensure var names are ensemblIDs
# - Ensure there `donor`, `sex`, `age`, `condition`, `publication`, `kit_10x`, `cell_or_nuclei` metadata at least
# - Concatenate

# %%
import scanpy as sc
import os
import json
import sys
import anndata

# %%
sys.path.append("/lustre/scratch126/cellgen/team205/jc48/jupyter/jctk") # add the directory containing the cloned jctk package to Python's path
import inspect
from jctk import api, utils

print("API module function names:\n", [f for f in dir(api) if inspect.isfunction(getattr(api, f))], "\n")
print("Utils module function names:\n", [f for f in dir(utils) if inspect.isfunction(getattr(utils, f))], "\n")
# Out:
# API module function names:
#  ['getClinVargenes', 'getHGNCgroup', 'getHGNCgroup_dict']
#
# Utils module function names:
#  ['add_genomic_coordinates', 'check_update', 'compute_median_count', 'downsample_adata_proportionately', 'downsample_adata_randomly', 'lognorm_to_counts_with_progress', 'rank_genes_vs_nearest', 'rename_adata_var_index', 'shapiro', 'test_normality']

# %% [markdown]
# # Prepare Chaffin22 data

# %%
Chaffin22=sc.read("/lustre/scratch126/cellgen/team205/heart/objects/hypersampling/diseased/RNA/Chaffin22/Chaffin22.h5ad")
Chaffin22
# Out:
# AnnData object with n_obs × n_vars = 592689 × 36601
#     obs: 'biosample_id', 'donor_id', 'disease', 'sex', 'age', 'lvef', 'cell_type_leiden0.6', 'SubCluster', 'cellbender_ncount', 'cellbender_ngenes', 'cellranger_percent_mito', 'exon_prop', 'cellbender_entropy', 'cellranger_doublet_scores'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'SubCluster_colors', 'biosample_id_colors', 'cell_type_leiden0.6_colors', 'disease_colors', 'donor_id_colors', 'log1p', 'sex_colors'
#     obsm: 'X_umap'
#     layers: 'cellbender_adjusted_counts', 'cellranger_raw'

# %%
Chaffin22.X.data[:10]
# Out:
# array([0.8174079 , 1.8014603 , 0.8174079 , 2.0738537 , 0.8174079 ,
#        0.48999685, 0.8174079 , 0.48999685, 0.8174079 , 0.48999685],
#       dtype=float32)

# %%
Chaffin22.X=Chaffin22.layers["cellbender_adjusted_counts"].copy()

# %%
Chaffin22.X.data[:10]
# Out:
# array([ 2.,  8.,  2., 11.,  2.,  1.,  2.,  1.,  2.,  1.], dtype=float32)

# %%
Chaffin22.obs['publication']="Chaffin22"

# %%
Chaffin22.obs['donor']=Chaffin22.obs['donor_id']

# %%
Chaffin22.obs['region']="LV"

# %%
Chaffin22.obs['disease'].value_counts()
# Out:
# HCM    235252
# NF     185441
# DCM    171996
# Name: disease, dtype: int64

# %%
Chaffin22.obs['condition'] = Chaffin22.obs['disease'].apply(lambda x: 'healthy' if x == 'NF' else x)

# %%
Chaffin22.obs['cell_or_nuclei']="Nuclei"

# %%
Chaffin22.obs['kit_10x']="3prime-v3"

# %%
Chaffin22.obs['cell_type']=Chaffin22.obs['cell_type_leiden0.6']
Chaffin22.obs['cell_state']=Chaffin22.obs['SubCluster']

# %%
Chaffin22.obs
# Out:
#                        biosample_id donor_id disease   sex   age  lvef  \
# TTCTTCCGTTCAACGT-1-0   LV_1622_2_nf    P1622      NF  male  56.0  65.0
# CATCCACCATCTAACG-1-0   LV_1622_2_nf    P1622      NF  male  56.0  65.0
# ACCCAAACAGCTAACT-1-0   LV_1622_2_nf    P1622      NF  male  56.0  65.0
# AAGGAATCAACTGGTT-1-0   LV_1622_2_nf    P1622      NF  male  56.0  65.0
# TACCCGTAGCGTGCTC-1-0   LV_1622_2_nf    P1622      NF  male  56.0  65.0
# ...                             ...      ...     ...   ...   ...   ...
# TTATTGCGTCGGTGTC-1-79  LV_1561_2_nf    P1561      NF  male  65.0  60.0
# GTCACGGGTTGTATGC-1-79  LV_1561_2_nf    P1561      NF  male  65.0  60.0
# GTCATGATCTTTCGAT-1-79  LV_1561_2_nf    P1561      NF  male  65.0  60.0
# GCGATCGTCAGAGTGG-1-79  LV_1561_2_nf    P1561      NF  male  65.0  60.0
# GCCCGAACAGAGAAAG-1-79  LV_1561_2_nf    P1561      NF  male  65.0  60.0
#
#                       cell_type_leiden0.6    SubCluster  cellbender_ncount  \
# TTCTTCCGTTCAACGT-1-0      Cardiomyocyte_I         CM-X1            15815.0
# CATCCACCATCTAACG-1-0      Cardiomyocyte_I      CM-HHATL            15546.0
# ACCCAAACAGCTAACT-1-0      Cardiomyocyte_I      CM-HHATL            14983.0
# AAGGAATCAACTGGTT-1-0      Cardiomyocyte_I         CM-X1            14995.0
# TACCCGTAGCGTGCTC-1-0      Cardiomyocyte_I      CM-HHATL            14797.0
# ...                                   ...           ...                ...
# TTATTGCGTCGGTGTC-1-79       Endothelial_I  EC-Lymphatic              403.0
# GTCACGGGTTGTATGC-1-79       Endothelial_I     EC-PKD1L1              494.0
# GTCATGATCTTTCGAT-1-79       Endothelial_I  EC-Lymphatic              502.0
# GCGATCGTCAGAGTGG-1-79       Endothelial_I  EC-Lymphatic              423.0
# GCCCGAACAGAGAAAG-1-79       Endothelial_I  EC-Lymphatic              428.0
#
#                        cellbender_ngenes  ...  cellbender_entropy  \
# TTCTTCCGTTCAACGT-1-0                4632  ...            7.503471
# CATCCACCATCTAACG-1-0                4673  ...            7.582058
# ACCCAAACAGCTAACT-1-0                4432  ...            7.466405
# AAGGAATCAACTGGTT-1-0                4483  ...            7.452266
# TACCCGTAGCGTGCTC-1-0                4690  ...            7.609082
# ...                                  ...  ...                 ...
# TTATTGCGTCGGTGTC-1-79                291  ...            6.691553
# GTCACGGGTTGTATGC-1-79                349  ...            6.791491
# GTCATGATCTTTCGAT-1-79                404  ...            7.409244
# GCGATCGTCAGAGTGG-1-79                343  ...            7.284163
# GCCCGAACAGAGAAAG-1-79                367  ...            7.642254
#
#                        cellranger_doublet_scores  publication  donor region  \
# TTCTTCCGTTCAACGT-1-0                    0.091892    Chaffin22  P1622     LV
# CATCCACCATCTAACG-1-0                    0.101727    Chaffin22  P1622     LV
# ACCCAAACAGCTAACT-1-0                    0.089618    Chaffin22  P1622     LV
# AAGGAATCAACTGGTT-1-0                    0.071875    Chaffin22  P1622     LV
# TACCCGTAGCGTGCTC-1-0                    0.063736    Chaffin22  P1622     LV
# ...                                          ...          ...    ...    ...
# TTATTGCGTCGGTGTC-1-79                   0.038961    Chaffin22  P1561     LV
# GTCACGGGTTGTATGC-1-79                   0.032258    Chaffin22  P1561     LV
# GTCATGATCTTTCGAT-1-79                   0.012023    Chaffin22  P1561     LV
# GCGATCGTCAGAGTGG-1-79                   0.009591    Chaffin22  P1561     LV
# GCCCGAACAGAGAAAG-1-79                   0.062837    Chaffin22  P1561     LV
#
#                       condition cell_or_nuclei    kit_10x        cell_type  \
# TTCTTCCGTTCAACGT-1-0    healthy         Nuclei  3prime-v3  Cardiomyocyte_I
# CATCCACCATCTAACG-1-0    healthy         Nuclei  3prime-v3  Cardiomyocyte_I
# ACCCAAACAGCTAACT-1-0    healthy         Nuclei  3prime-v3  Cardiomyocyte_I
# AAGGAATCAACTGGTT-1-0    healthy         Nuclei  3prime-v3  Cardiomyocyte_I
# TACCCGTAGCGTGCTC-1-0    healthy         Nuclei  3prime-v3  Cardiomyocyte_I
# ...                         ...            ...        ...              ...
# TTATTGCGTCGGTGTC-1-79   healthy         Nuclei  3prime-v3    Endothelial_I
# GTCACGGGTTGTATGC-1-79   healthy         Nuclei  3prime-v3    Endothelial_I
# GTCATGATCTTTCGAT-1-79   healthy         Nuclei  3prime-v3    Endothelial_I
# GCGATCGTCAGAGTGG-1-79   healthy         Nuclei  3prime-v3    Endothelial_I
# GCCCGAACAGAGAAAG-1-79   healthy         Nuclei  3prime-v3    Endothelial_I
#
#                          cell_state
# TTCTTCCGTTCAACGT-1-0          CM-X1
# CATCCACCATCTAACG-1-0       CM-HHATL
# ACCCAAACAGCTAACT-1-0       CM-HHATL
# AAGGAATCAACTGGTT-1-0          CM-X1
# TACCCGTAGCGTGCTC-1-0       CM-HHATL
# ...                             ...
# TTATTGCGTCGGTGTC-1-79  EC-Lymphatic
# GTCACGGGTTGTATGC-1-79     EC-PKD1L1
# GTCATGATCTTTCGAT-1-79  EC-Lymphatic
# GCGATCGTCAGAGTGG-1-79  EC-Lymphatic
# GCCCGAACAGAGAAAG-1-79  EC-Lymphatic
#
# [592689 rows x 22 columns]

# %%
Chaffin22.var
# Out:
#                     gene_ids    feature_types                 genome
# MIR1302-2HG  ENSG00000243485  Gene Expression  GRCh38-2020-A_premrna
# FAM138A      ENSG00000237613  Gene Expression  GRCh38-2020-A_premrna
# OR4F5        ENSG00000186092  Gene Expression  GRCh38-2020-A_premrna
# AL627309.1   ENSG00000238009  Gene Expression  GRCh38-2020-A_premrna
# AL627309.3   ENSG00000239945  Gene Expression  GRCh38-2020-A_premrna
# ...                      ...              ...                    ...
# AC141272.1   ENSG00000277836  Gene Expression  GRCh38-2020-A_premrna
# AC023491.2   ENSG00000278633  Gene Expression  GRCh38-2020-A_premrna
# AC007325.1   ENSG00000276017  Gene Expression  GRCh38-2020-A_premrna
# AC007325.4   ENSG00000278817  Gene Expression  GRCh38-2020-A_premrna
# AC007325.2   ENSG00000277196  Gene Expression  GRCh38-2020-A_premrna
#
# [36601 rows x 3 columns]

# %%
utils.rename_adata_var_index(Chaffin22,"gene_ids")
# Out:
# /lustre/scratch126/cellgen/team205/jc48/miniconda3/envs/omni_env/lib/python3.11/site-packages/anndata/_core/anndata.py:887: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     ['ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945']
#
#     Inferred to be: categorical
#
#   names = self._prep_dim_index(names, "var")
# AnnData object with n_obs × n_vars = 592689 × 36601
#     obs: 'biosample_id', 'donor_id', 'disease', 'sex', 'age', 'lvef', 'cell_type_leiden0.6', 'SubCluster', 'cellbender_ncount', 'cellbender_ngenes', 'cellranger_percent_mito', 'exon_prop', 'cellbender_entropy', 'cellranger_doublet_scores', 'publication', 'donor', 'region', 'condition', 'cell_or_nuclei', 'kit_10x', 'cell_type', 'cell_state'
#     var: 'original_index', 'gene_ids', 'feature_types', 'genome'
#     uns: 'SubCluster_colors', 'biosample_id_colors', 'cell_type_leiden0.6_colors', 'disease_colors', 'donor_id_colors', 'log1p', 'sex_colors'
#     obsm: 'X_umap'
#     layers: 'cellbender_adjusted_counts', 'cellranger_raw'

# %%
Chaffin22.var
# Out:
#                 original_index         gene_ids    feature_types  \
# gene_ids
# ENSG00000243485    MIR1302-2HG  ENSG00000243485  Gene Expression
# ENSG00000237613        FAM138A  ENSG00000237613  Gene Expression
# ENSG00000186092          OR4F5  ENSG00000186092  Gene Expression
# ENSG00000238009     AL627309.1  ENSG00000238009  Gene Expression
# ENSG00000239945     AL627309.3  ENSG00000239945  Gene Expression
# ...                        ...              ...              ...
# ENSG00000277836     AC141272.1  ENSG00000277836  Gene Expression
# ENSG00000278633     AC023491.2  ENSG00000278633  Gene Expression
# ENSG00000276017     AC007325.1  ENSG00000276017  Gene Expression
# ENSG00000278817     AC007325.4  ENSG00000278817  Gene Expression
# ENSG00000277196     AC007325.2  ENSG00000277196  Gene Expression
#
#                                 genome
# gene_ids
# ENSG00000243485  GRCh38-2020-A_premrna
# ENSG00000237613  GRCh38-2020-A_premrna
# ENSG00000186092  GRCh38-2020-A_premrna
# ENSG00000238009  GRCh38-2020-A_premrna
# ENSG00000239945  GRCh38-2020-A_premrna
# ...                                ...
# ENSG00000277836  GRCh38-2020-A_premrna
# ENSG00000278633  GRCh38-2020-A_premrna
# ENSG00000276017  GRCh38-2020-A_premrna
# ENSG00000278817  GRCh38-2020-A_premrna
# ENSG00000277196  GRCh38-2020-A_premrna
#
# [36601 rows x 4 columns]

# %% [markdown]
# # Prepare Reichart22 data

# %%
Reichart22=sc.read("/lustre/scratch126/cellgen/team205/heart/objects/hypersampling/diseased/RNA/Reichart22/Reichart22.h5ad")
Reichart22
# Out:
# AnnData object with n_obs × n_vars = 881081 × 33234
#     obs: 'Sample', 'donor_id', 'Region_x', 'Primary.Genetic.Diagnosis', 'n_genes', 'n_counts', 'percent_mito', 'percent_ribo', 'scrublet_score_z', 'scrublet_score_log', 'solo_score', 'cell_states', 'Assigned', 'self_reported_ethnicity_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'sex_ontology_term_id', 'assay_ontology_term_id', 'organism_ontology_term_id', 'is_primary_data', 'tissue_ontology_term_id', 'development_stage_ontology_term_id', 'suspension_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype'
#     uns: 'Primary.Genetic.Diagnosis_colors', 'Region_x_colors', 'cell_states_colors', 'cell_type_colors', 'cell_type_ontology_term_id_colors', 'leiden', 'neighbors', 'pca', 'schema_version', 'title', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'counts'

# %%
Reichart22.X.data[:10]
# Out:
# array([2.1988854, 1.3006421, 1.3006421, 1.8474003, 1.3006421, 1.3006421,
#        2.1988854, 1.3006421, 1.3006421, 1.3006421], dtype=float32)

# %%
Reichart22.X=Reichart22.layers["counts"].copy()

# %%
Reichart22.X.data[:10]
# Out:
# array([1, 1, 1, 1, 1, 2, 1, 1, 1, 1], dtype=int32)

# %%
Reichart22.obs['publication']="Reichart22"

# %%
Reichart22.obs["tissue"].value_counts()
# Out:
# heart left ventricle       419113
# heart right ventricle      230723
# interventricular septum    206873
# apex of heart               24372
# Name: tissue, dtype: int64

# %%
Reichart22=Reichart22[Reichart22.obs.tissue!="heart right ventricle"]
Reichart22
# Out:
# View of AnnData object with n_obs × n_vars = 650358 × 33234
#     obs: 'Sample', 'donor_id', 'Region_x', 'Primary.Genetic.Diagnosis', 'n_genes', 'n_counts', 'percent_mito', 'percent_ribo', 'scrublet_score_z', 'scrublet_score_log', 'solo_score', 'cell_states', 'Assigned', 'self_reported_ethnicity_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'sex_ontology_term_id', 'assay_ontology_term_id', 'organism_ontology_term_id', 'is_primary_data', 'tissue_ontology_term_id', 'development_stage_ontology_term_id', 'suspension_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'publication'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype'
#     uns: 'Primary.Genetic.Diagnosis_colors', 'Region_x_colors', 'cell_states_colors', 'cell_type_colors', 'cell_type_ontology_term_id_colors', 'leiden', 'neighbors', 'pca', 'schema_version', 'title', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'counts'

# %%
def add_region_column(adata):
    # Define a dictionary to map tissue values to region values
    tissue_to_region = {
        "heart left ventricle": "LV",
        "interventricular septum": "SP",
        "apex of heart": "AX"
    }

    # Create a new column 'region' by mapping the 'tissue' column using the dictionary
    adata.obs['region'] = adata.obs['tissue'].map(tissue_to_region)

    return adata

# Assuming Reichart22 is your anndata object, apply the function to add the 'region' column
Reichart22 = add_region_column(Reichart22)
# Out:
# /tmp/ipykernel_128351/3240009553.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs['region'] = adata.obs['tissue'].map(tissue_to_region)

# %%
Reichart22.obs["region"].value_counts()
# Out:
# LV    419113
# SP    206873
# AX     24372
# Name: region, dtype: int64

# %%
Reichart22.obs["disease"].value_counts()
# Out:
# dilated cardiomyopathy                             349797
# normal                                             219149
# arrhythmogenic right ventricular cardiomyopathy     73849
# non-compaction cardiomyopathy                        7563
# Name: disease, dtype: int64

# %%
def add_condition_column(adata):
    # Define a dictionary to map disease values to condition values
    disease_to_condition = {
        "normal": "healthy",
        "arrhythmogenic right ventricular cardiomyopathy": "ARVC",
        "dilated cardiomyopathy": "DCM",
        "non-compaction cardiomyopathy": "LVNC"
    }

    # Create a new column 'condition' by mapping the 'disease' column using the dictionary
    adata.obs['condition'] = adata.obs['disease'].map(disease_to_condition)

    return adata

# Assuming Reichart22 is your anndata object, apply the function to add the 'condition' column
Reichart22 = add_condition_column(Reichart22)

# %%
Reichart22.obs["condition"].value_counts()
# Out:
# DCM        349797
# healthy    219149
# ARVC        73849
# LVNC         7563
# Name: condition, dtype: int64

# %%
Reichart22=Reichart22[Reichart22.obs.condition.isin(["healthy","DCM"])]

# %%
def add_age_column(adata):
    # Define a dictionary to map development stages to the average age
    stage_to_age = {
        "fifth decade human stage": 45,
        "sixth decade human stage": 55,
        "seventh decade human stage": 65,
        "fourth decade human stage": 35,
        "eighth decade human stage": 75,
        "adolescent stage": 15,  # Assuming adolescent refers to ages 10-19
        "young adult stage": 25,  # Assuming young adult refers to ages 20-29
        "third decade human stage": 25,  # Overlaps with young adult stage
        "infant stage": 5,  # Assuming infant refers to ages 0-9
        "child stage": 5  # Overlaps with infant stage
    }
    
    # Create a new column 'age' by mapping the 'development_stage' column using the dictionary
    adata.obs['age'] = adata.obs['development_stage'].map(stage_to_age)
    
    return adata

# Assuming Reichart22 is your anndata object, apply the function to add the 'age' column
Reichart22 = add_age_column(Reichart22)
# Out:
# /tmp/ipykernel_128351/2591926804.py:17: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs['age'] = adata.obs['development_stage'].map(stage_to_age)

# %%
Reichart22.obs['cell_type']=Reichart22.obs['cell_type']
Reichart22.obs['cell_state']=Reichart22.obs['cell_states']

# %%
Reichart22.obs
# Out:
#                     Sample donor_id Region_x Primary.Genetic.Diagnosis  \
# 2428    BS_H25_S00_premrna       H3       LV                   control
# 2429    BS_H25_S00_premrna       H3       LV                   control
# 2430    BS_H25_S00_premrna       H3       LV                   control
# 2431    BS_H25_S00_premrna       H3       LV                   control
# 2432    BS_H25_S00_premrna       H3       LV                   control
# ...                    ...      ...      ...                       ...
# 878977  IC_H04_LV0_premrna   IC_H04       LV                     PVneg
# 878978  IC_H04_LV0_premrna   IC_H04       LV                     PVneg
# 878979  IC_H04_LV0_premrna   IC_H04       LV                     PVneg
# 878980  IC_H04_LV0_premrna   IC_H04       LV                     PVneg
# 878981  IC_H04_LV0_premrna   IC_H04       LV                     PVneg
#
#         n_genes  n_counts  percent_mito  percent_ribo  scrublet_score_z  \
# 2428        649       907      0.004410      0.002205          0.017023
# 2429       1479      2659      0.000376      0.002256          0.033552
# 2430        716      1157      0.000864      0.000864          0.043906
# 2431        753      1055      0.007583      0.000000          0.094017
# 2432        429       603      0.001658      0.001658          0.021382
# ...         ...       ...           ...           ...               ...
# 878977     2292      4195      0.003337      0.002145          0.017964
# 878978      446       516      0.000000      0.000000          0.014629
# 878979     2756      6429      0.001400      0.001089          0.016749
# 878980     2618      6587      0.003492      0.001670          0.014629
# 878981     2402      5080      0.001181      0.000787          0.012048
#
#         scrublet_score_log  ...      organism     sex  \
# 2428              0.129609  ...  Homo sapiens    male
# 2429              0.022799  ...  Homo sapiens    male
# 2430              0.000817  ...  Homo sapiens    male
# 2431              0.066094  ...  Homo sapiens    male
# 2432              0.021382  ...  Homo sapiens    male
# ...                    ...  ...           ...     ...
# 878977            0.007822  ...  Homo sapiens  female
# 878978            0.006115  ...  Homo sapiens  female
# 878979            0.007822  ...  Homo sapiens  female
# 878980            0.010629  ...  Homo sapiens  female
# 878981            0.010629  ...  Homo sapiens  female
#
#                          tissue self_reported_ethnicity  \
# 2428    interventricular septum                   Asian
# 2429    interventricular septum                   Asian
# 2430    interventricular septum                   Asian
# 2431    interventricular septum                   Asian
# 2432    interventricular septum                   Asian
# ...                         ...                     ...
# 878977     heart left ventricle                European
# 878978     heart left ventricle                European
# 878979     heart left ventricle                European
# 878980     heart left ventricle                European
# 878981     heart left ventricle                European
#
#                  development_stage publication region condition age  \
# 2428      sixth decade human stage  Reichart22     SP   healthy  55
# 2429      sixth decade human stage  Reichart22     SP   healthy  55
# 2430      sixth decade human stage  Reichart22     SP   healthy  55
# 2431      sixth decade human stage  Reichart22     SP   healthy  55
# 2432      sixth decade human stage  Reichart22     SP   healthy  55
# ...                            ...         ...    ...       ...  ..
# 878977  seventh decade human stage  Reichart22     LV       DCM  65
# 878978  seventh decade human stage  Reichart22     LV       DCM  65
# 878979  seventh decade human stage  Reichart22     LV       DCM  65
# 878980  seventh decade human stage  Reichart22     LV       DCM  65
# 878981  seventh decade human stage  Reichart22     LV       DCM  65
#
#         cell_state
# 2428        SMC1.2
# 2429        vCM1.0
# 2430          vCM2
# 2431         EC8.0
# 2432           PC1
# ...            ...
# 878977       EC2.0
# 878978        vFB3
# 878979        vFB2
# 878980    PC_lowQC
# 878981        vFB4
#
# [568946 rows x 36 columns]

# %%
Reichart22.obs["donor"]=Reichart22.obs["donor_id"]

# %%
Reichart22.obs['cell_or_nuclei']="Nuclei"

# %%
Reichart22.obs['kit_10x']="3prime-v3"

# %%
Reichart22.obs
# Out:
#                     Sample donor_id Region_x Primary.Genetic.Diagnosis  \
# 2428    BS_H25_S00_premrna       H3       LV                   control
# 2429    BS_H25_S00_premrna       H3       LV                   control
# 2430    BS_H25_S00_premrna       H3       LV                   control
# 2431    BS_H25_S00_premrna       H3       LV                   control
# 2432    BS_H25_S00_premrna       H3       LV                   control
# ...                    ...      ...      ...                       ...
# 878977  IC_H04_LV0_premrna   IC_H04       LV                     PVneg
# 878978  IC_H04_LV0_premrna   IC_H04       LV                     PVneg
# 878979  IC_H04_LV0_premrna   IC_H04       LV                     PVneg
# 878980  IC_H04_LV0_premrna   IC_H04       LV                     PVneg
# 878981  IC_H04_LV0_premrna   IC_H04       LV                     PVneg
#
#         n_genes  n_counts  percent_mito  percent_ribo  scrublet_score_z  \
# 2428        649       907      0.004410      0.002205          0.017023
# 2429       1479      2659      0.000376      0.002256          0.033552
# 2430        716      1157      0.000864      0.000864          0.043906
# 2431        753      1055      0.007583      0.000000          0.094017
# 2432        429       603      0.001658      0.001658          0.021382
# ...         ...       ...           ...           ...               ...
# 878977     2292      4195      0.003337      0.002145          0.017964
# 878978      446       516      0.000000      0.000000          0.014629
# 878979     2756      6429      0.001400      0.001089          0.016749
# 878980     2618      6587      0.003492      0.001670          0.014629
# 878981     2402      5080      0.001181      0.000787          0.012048
#
#         scrublet_score_log  ...  self_reported_ethnicity  \
# 2428              0.129609  ...                    Asian
# 2429              0.022799  ...                    Asian
# 2430              0.000817  ...                    Asian
# 2431              0.066094  ...                    Asian
# 2432              0.021382  ...                    Asian
# ...                    ...  ...                      ...
# 878977            0.007822  ...                 European
# 878978            0.006115  ...                 European
# 878979            0.007822  ...                 European
# 878980            0.010629  ...                 European
# 878981            0.010629  ...                 European
#
#                  development_stage  publication region condition age  \
# 2428      sixth decade human stage   Reichart22     SP   healthy  55
# 2429      sixth decade human stage   Reichart22     SP   healthy  55
# 2430      sixth decade human stage   Reichart22     SP   healthy  55
# 2431      sixth decade human stage   Reichart22     SP   healthy  55
# 2432      sixth decade human stage   Reichart22     SP   healthy  55
# ...                            ...          ...    ...       ...  ..
# 878977  seventh decade human stage   Reichart22     LV       DCM  65
# 878978  seventh decade human stage   Reichart22     LV       DCM  65
# 878979  seventh decade human stage   Reichart22     LV       DCM  65
# 878980  seventh decade human stage   Reichart22     LV       DCM  65
# 878981  seventh decade human stage   Reichart22     LV       DCM  65
#
#        cell_state   donor cell_or_nuclei    kit_10x
# 2428       SMC1.2      H3         Nuclei  3prime-v3
# 2429       vCM1.0      H3         Nuclei  3prime-v3
# 2430         vCM2      H3         Nuclei  3prime-v3
# 2431        EC8.0      H3         Nuclei  3prime-v3
# 2432          PC1      H3         Nuclei  3prime-v3
# ...           ...     ...            ...        ...
# 878977      EC2.0  IC_H04         Nuclei  3prime-v3
# 878978       vFB3  IC_H04         Nuclei  3prime-v3
# 878979       vFB2  IC_H04         Nuclei  3prime-v3
# 878980   PC_lowQC  IC_H04         Nuclei  3prime-v3
# 878981       vFB4  IC_H04         Nuclei  3prime-v3
#
# [568946 rows x 39 columns]

# %%
Reichart22.var
# Out:
#                  feature_is_filtered       feature_name feature_reference  \
# gene_ids
# ENSG00000243485                False        MIR1302-2HG    NCBITaxon:9606
# ENSG00000237613                False            FAM138A    NCBITaxon:9606
# ENSG00000186092                False              OR4F5    NCBITaxon:9606
# ENSG00000238009                False       RP11-34P13.7    NCBITaxon:9606
# ENSG00000239945                False       RP11-34P13.8    NCBITaxon:9606
# ...                              ...                ...               ...
# ENSG00000277856                False  ENSG00000277856.1    NCBITaxon:9606
# ENSG00000275063                False  ENSG00000275063.1    NCBITaxon:9606
# ENSG00000271254                False  ENSG00000271254.6    NCBITaxon:9606
# ENSG00000277475                False  ENSG00000277475.1    NCBITaxon:9606
# ENSG00000268674                False  ENSG00000268674.2    NCBITaxon:9606
#
#                 feature_biotype
# gene_ids
# ENSG00000243485            gene
# ENSG00000237613            gene
# ENSG00000186092            gene
# ENSG00000238009            gene
# ENSG00000239945            gene
# ...                         ...
# ENSG00000277856            gene
# ENSG00000275063            gene
# ENSG00000271254            gene
# ENSG00000277475            gene
# ENSG00000268674            gene
#
# [33234 rows x 4 columns]

# %% [markdown]
# # Prepare atlas

# %%
EightRegions=sc.read("/lustre/scratch126/cellgen/team205/heart/objects/hypersampling/RNA/8regions/RNA_adult-8reg_full_raw_cellstate-annotated.h5ad")
EightRegions
# Out:
# AnnData object with n_obs × n_vars = 704296 × 32732
#     obs: 'sangerID', 'combinedID', 'donor', 'donor_type', 'region', 'region_finest', 'age', 'gender', 'facility', 'cell_or_nuclei', 'modality', 'kit_10x', 'flushed', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'scrublet_score', 'scrublet_leiden', 'cluster_scrublet_score', 'doublet_pval', 'doublet_bh_pval', 'batch_key', 'leiden_scVI', 'cell_type', 'cell_state_HCAv1', 'cell_state_scNym', 'cell_state_scNym_confidence', 'cell_state', 'latent_RT_efficiency', 'latent_cell_probability', 'latent_scale', 'n_counts', '_scvi_batch', '_scvi_labels', 'clus20', 'doublet_cls', 'original_or_new', 'batch', 'scANVI_predictions', 'leiden_scArches'
#     var: 'gene_name-new', 'gene_name_scRNA-0-original', 'gene_name_snRNA-1-original', 'gene_name_multiome-2-original'
#     uns: 'age_colors', 'cell_or_nuclei_colors', 'cell_state_colors', 'cell_type_colors', 'donor_colors', 'donor_type_colors', 'facility_colors', 'flushed_colors', 'gender_colors', 'kit_10x_colors', 'leiden', 'modality_colors', 'neighbors', 'original_or_new_colors', 'region_colors', 'region_finest_colors', 'scANVI_predictions_colors', 'umap'
#     obsm: 'X_scArches', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
EightRegions.obs.region.value_counts()
# Out:
# LV     148429
# RV     104454
# AX     102221
# SP      99024
# LA      74501
# SAN     69153
# RA      57495
# AVN     49019
# Name: region, dtype: int64

# %%
EightRegions=EightRegions[EightRegions.obs.region.isin(["LV","AX","SP"])]
EightRegions
# Out:
# View of AnnData object with n_obs × n_vars = 349674 × 32732
#     obs: 'sangerID', 'combinedID', 'donor', 'donor_type', 'region', 'region_finest', 'age', 'gender', 'facility', 'cell_or_nuclei', 'modality', 'kit_10x', 'flushed', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'scrublet_score', 'scrublet_leiden', 'cluster_scrublet_score', 'doublet_pval', 'doublet_bh_pval', 'batch_key', 'leiden_scVI', 'cell_type', 'cell_state_HCAv1', 'cell_state_scNym', 'cell_state_scNym_confidence', 'cell_state', 'latent_RT_efficiency', 'latent_cell_probability', 'latent_scale', 'n_counts', '_scvi_batch', '_scvi_labels', 'clus20', 'doublet_cls', 'original_or_new', 'batch', 'scANVI_predictions', 'leiden_scArches'
#     var: 'gene_name-new', 'gene_name_scRNA-0-original', 'gene_name_snRNA-1-original', 'gene_name_multiome-2-original'
#     uns: 'age_colors', 'cell_or_nuclei_colors', 'cell_state_colors', 'cell_type_colors', 'donor_colors', 'donor_type_colors', 'facility_colors', 'flushed_colors', 'gender_colors', 'kit_10x_colors', 'leiden', 'modality_colors', 'neighbors', 'original_or_new_colors', 'region_colors', 'region_finest_colors', 'scANVI_predictions_colors', 'umap'
#     obsm: 'X_scArches', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
EightRegions.X.data[:10]
# Out:
# array([1., 1., 1., 1., 2., 1., 1., 1., 5., 1.], dtype=float32)

# %%
EightRegions.obs['publication']="Kanemaru22"
# Out:
# /tmp/ipykernel_128351/3559308934.py:1: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   EightRegions.obs['publication']="Kanemaru22"

# %%
EightRegions.obs['condition']="healthy"

# %%
EightRegions.obs['sex']=EightRegions.obs['gender']

# %%
import numpy as np

def convert_age_to_numeric(adata):
    # Function to convert age value to numeric, taking the mean of age bands
    def age_to_numeric(age):
        if isinstance(age, str):
            # Split the string by '-' and take the mean of the two values
            age_values = age.split('-')
            return np.mean([float(val) for val in age_values])
        else:
            # If the age is already numeric, return it as is
            return age

    # Apply the function to each value in the 'age' column
    adata.obs['age'] = adata.obs['age'].apply(age_to_numeric)
    
    return adata

# Assuming adata is your anndata object, apply the function to convert age values to numeric
EightRegions = convert_age_to_numeric(EightRegions)

# %%
EightRegions.obs
# Out:
#                                                               sangerID  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                       HCAHeart7606896
# HCAHeart7606896_CGCTTCACATTTGCCC                       HCAHeart7606896
# HCAHeart7606896_GTTAAGCAGAGACTAT                       HCAHeart7606896
# HCAHeart7606896_TCGCGTTGTAAGAGGA                       HCAHeart7606896
# HCAHeart7606896_GCTGCGAGTGTTGGGA                       HCAHeart7606896
# ...                                                                ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...  HCAHeartST11064577
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...  HCAHeartST11064577
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...  HCAHeartST11064577
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...  HCAHeartST11064577
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...  HCAHeartST11064577
#
#                                                                                combinedID  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                                                       na
# HCAHeart7606896_CGCTTCACATTTGCCC                                                       na
# HCAHeart7606896_GTTAAGCAGAGACTAT                                                       na
# HCAHeart7606896_TCGCGTTGTAAGAGGA                                                       na
# HCAHeart7606896_GCTGCGAGTGTTGGGA                                                       na
# ...                                                                                   ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...  HCAHeartST11064577_HCAHeartST11023242
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...  HCAHeartST11064577_HCAHeartST11023242
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...  HCAHeartST11064577_HCAHeartST11023242
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...  HCAHeartST11064577_HCAHeartST11023242
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...  HCAHeartST11064577_HCAHeartST11023242
#
#                                                    donor donor_type region  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                      D1        DBD     AX
# HCAHeart7606896_CGCTTCACATTTGCCC                      D1        DBD     AX
# HCAHeart7606896_GTTAAGCAGAGACTAT                      D1        DBD     AX
# HCAHeart7606896_TCGCGTTGTAAGAGGA                      D1        DBD     AX
# HCAHeart7606896_GCTGCGAGTGTTGGGA                      D1        DBD     AX
# ...                                                  ...        ...    ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...   AH1        DCD     SP
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...   AH1        DCD     SP
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...   AH1        DCD     SP
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...   AH1        DCD     SP
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...   AH1        DCD     SP
#
#                                                    region_finest   age  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                              AX  52.5
# HCAHeart7606896_CGCTTCACATTTGCCC                              AX  52.5
# HCAHeart7606896_GTTAAGCAGAGACTAT                              AX  52.5
# HCAHeart7606896_TCGCGTTGTAAGAGGA                              AX  52.5
# HCAHeart7606896_GCTGCGAGTGTTGGGA                              AX  52.5
# ...                                                          ...   ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...    IVS MID LV  47.5
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...    IVS MID LV  47.5
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...    IVS MID LV  47.5
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...    IVS MID LV  47.5
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...    IVS MID LV  47.5
#
#                                                     gender facility  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                    Female   Sanger
# HCAHeart7606896_CGCTTCACATTTGCCC                    Female   Sanger
# HCAHeart7606896_GTTAAGCAGAGACTAT                    Female   Sanger
# HCAHeart7606896_TCGCGTTGTAAGAGGA                    Female   Sanger
# HCAHeart7606896_GCTGCGAGTGTTGGGA                    Female   Sanger
# ...                                                    ...      ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...  Female   Sanger
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...  Female   Sanger
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...  Female   Sanger
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...  Female   Sanger
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...  Female   Sanger
#
#                                                    cell_or_nuclei  ...  \
# barcode                                                            ...
# HCAHeart7606896_GATGAGGCACGGCTAC                             Cell  ...
# HCAHeart7606896_CGCTTCACATTTGCCC                             Cell  ...
# HCAHeart7606896_GTTAAGCAGAGACTAT                             Cell  ...
# HCAHeart7606896_TCGCGTTGTAAGAGGA                             Cell  ...
# HCAHeart7606896_GCTGCGAGTGTTGGGA                             Cell  ...
# ...                                                           ...  ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...         Nuclei  ...
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...         Nuclei  ...
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...         Nuclei  ...
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...         Nuclei  ...
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...         Nuclei  ...
#
#                                                    _scvi_labels clus20  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                            NaN     No
# HCAHeart7606896_CGCTTCACATTTGCCC                            NaN     No
# HCAHeart7606896_GTTAAGCAGAGACTAT                            NaN     No
# HCAHeart7606896_TCGCGTTGTAAGAGGA                            NaN     No
# HCAHeart7606896_GCTGCGAGTGTTGGGA                            NaN     No
# ...                                                         ...    ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...          NaN     No
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...          NaN     No
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...          NaN     No
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...          NaN     No
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...          NaN     No
#
#                                                    doublet_cls  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                           nan
# HCAHeart7606896_CGCTTCACATTTGCCC                           nan
# HCAHeart7606896_GTTAAGCAGAGACTAT                           nan
# HCAHeart7606896_TCGCGTTGTAAGAGGA                           nan
# HCAHeart7606896_GCTGCGAGTGTTGGGA                           nan
# ...                                                        ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...         nan
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...         nan
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...         nan
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...         nan
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...         nan
#
#                                                     original_or_new  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                           original
# HCAHeart7606896_CGCTTCACATTTGCCC                           original
# HCAHeart7606896_GTTAAGCAGAGACTAT                           original
# HCAHeart7606896_TCGCGTTGTAAGAGGA                           original
# HCAHeart7606896_GCTGCGAGTGTTGGGA                           original
# ...                                                             ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...         original
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...         original
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...         original
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...         original
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...         original
#
#                                                                      batch  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                         D1_Cell_3prime-v2
# HCAHeart7606896_CGCTTCACATTTGCCC                         D1_Cell_3prime-v2
# HCAHeart7606896_GTTAAGCAGAGACTAT                         D1_Cell_3prime-v2
# HCAHeart7606896_TCGCGTTGTAAGAGGA                         D1_Cell_3prime-v2
# HCAHeart7606896_GCTGCGAGTGTTGGGA                         D1_Cell_3prime-v2
# ...                                                                    ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...  AH1_Nuclei_Multiome-v1
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...  AH1_Nuclei_Multiome-v1
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...  AH1_Nuclei_Multiome-v1
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...  AH1_Nuclei_Multiome-v1
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...  AH1_Nuclei_Multiome-v1
#
#                                                            scANVI_predictions  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                             Endothelial cell
# HCAHeart7606896_CGCTTCACATTTGCCC                                   Mural cell
# HCAHeart7606896_GTTAAGCAGAGACTAT                             Endothelial cell
# HCAHeart7606896_TCGCGTTGTAAGAGGA                                   Mural cell
# HCAHeart7606896_GCTGCGAGTGTTGGGA                             Endothelial cell
# ...                                                                       ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...           Endothelial cell
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...                    Myeloid
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...  Ventricular Cardiomyocyte
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...                    Myeloid
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...                    Myeloid
#
#                                                     leiden_scArches  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                                 10
# HCAHeart7606896_CGCTTCACATTTGCCC                                 18
# HCAHeart7606896_GTTAAGCAGAGACTAT                                 10
# HCAHeart7606896_TCGCGTTGTAAGAGGA                                  3
# HCAHeart7606896_GCTGCGAGTGTTGGGA                                 10
# ...                                                             ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...               29
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...               29
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...               13
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...               12
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...               29
#
#                                                     publication  condition  \
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                     Kanemaru22    healthy
# HCAHeart7606896_CGCTTCACATTTGCCC                     Kanemaru22    healthy
# HCAHeart7606896_GTTAAGCAGAGACTAT                     Kanemaru22    healthy
# HCAHeart7606896_TCGCGTTGTAAGAGGA                     Kanemaru22    healthy
# HCAHeart7606896_GCTGCGAGTGTTGGGA                     Kanemaru22    healthy
# ...                                                         ...        ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...   Kanemaru22    healthy
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...   Kanemaru22    healthy
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...   Kanemaru22    healthy
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...   Kanemaru22    healthy
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...   Kanemaru22    healthy
#
#                                                        sex
# barcode
# HCAHeart7606896_GATGAGGCACGGCTAC                    Female
# HCAHeart7606896_CGCTTCACATTTGCCC                    Female
# HCAHeart7606896_GTTAAGCAGAGACTAT                    Female
# HCAHeart7606896_TCGCGTTGTAAGAGGA                    Female
# HCAHeart7606896_GCTGCGAGTGTTGGGA                    Female
# ...                                                    ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...  Female
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...  Female
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...  Female
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...  Female
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...  Female
#
# [349674 rows x 47 columns]

# %%
EightRegions.var
# Out:
#                 gene_name-new gene_name_scRNA-0-original  \
# ENSG00000243485   MIR1302-2HG                MIR1302-2HG
# ENSG00000237613       FAM138A                    FAM138A
# ENSG00000186092         OR4F5                      OR4F5
# ENSG00000238009    AL627309.1                 AL627309.1
# ENSG00000239945    AL627309.3                 AL627309.3
# ...                       ...                        ...
# ENSG00000277856    AC233755.2                 AC233755.2
# ENSG00000275063    AC233755.1                 AC233755.1
# ENSG00000271254    AC240274.1                 AC240274.1
# ENSG00000277475    AC213203.2                 AC213203.1
# ENSG00000268674    AC213203.1                    FAM231C
#
#                 gene_name_snRNA-1-original gene_name_multiome-2-original
# ENSG00000243485                MIR1302-2HG                   MIR1302-2HG
# ENSG00000237613                    FAM138A                       FAM138A
# ENSG00000186092                      OR4F5                         OR4F5
# ENSG00000238009                 AL627309.1                    AL627309.1
# ENSG00000239945                 AL627309.3                    AL627309.3
# ...                                    ...                           ...
# ENSG00000277856                 AC233755.2                    AC233755.2
# ENSG00000275063                 AC233755.1                    AC233755.1
# ENSG00000271254                 AC240274.1                    AC240274.1
# ENSG00000277475                 AC213203.1                    AC213203.2
# ENSG00000268674                    FAM231C                    AC213203.1
#
# [32732 rows x 4 columns]

# %% [markdown]
# # Concatenate into one large LV object

# %%
# %%time
adata=anndata.concat([Chaffin22, Reichart22, EightRegions], join='outer')
adata
# Out:
# /lustre/scratch126/cellgen/team205/jc48/miniconda3/envs/omni_env/lib/python3.11/site-packages/anndata/_core/merge.py:1111: UserWarning: Only some AnnData objects have `.raw` attribute, not concatenating `.raw` attributes.
#   warn(
# CPU times: user 1min 10s, sys: 3min 9s, total: 4min 19s
# Wall time: 4min 19s
# AnnData object with n_obs × n_vars = 1511309 × 37171
#     obs: 'biosample_id', 'donor_id', 'disease', 'sex', 'age', 'lvef', 'cell_type_leiden0.6', 'SubCluster', 'cellbender_ncount', 'cellbender_ngenes', 'cellranger_percent_mito', 'exon_prop', 'cellbender_entropy', 'cellranger_doublet_scores', 'publication', 'donor', 'region', 'condition', 'cell_or_nuclei', 'kit_10x', 'cell_type', 'cell_state', 'Sample', 'Region_x', 'Primary.Genetic.Diagnosis', 'n_genes', 'n_counts', 'percent_mito', 'percent_ribo', 'scrublet_score_z', 'scrublet_score_log', 'solo_score', 'cell_states', 'Assigned', 'self_reported_ethnicity_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'sex_ontology_term_id', 'assay_ontology_term_id', 'organism_ontology_term_id', 'is_primary_data', 'tissue_ontology_term_id', 'development_stage_ontology_term_id', 'suspension_type', 'assay', 'organism', 'tissue', 'self_reported_ethnicity', 'development_stage', 'sangerID', 'combinedID', 'donor_type', 'region_finest', 'gender', 'facility', 'modality', 'flushed', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'scrublet_score', 'scrublet_leiden', 'cluster_scrublet_score', 'doublet_pval', 'doublet_bh_pval', 'batch_key', 'leiden_scVI', 'cell_state_HCAv1', 'cell_state_scNym', 'cell_state_scNym_confidence', 'latent_RT_efficiency', 'latent_cell_probability', 'latent_scale', '_scvi_batch', '_scvi_labels', 'clus20', 'doublet_cls', 'original_or_new', 'batch', 'scANVI_predictions', 'leiden_scArches'
#     obsm: 'X_umap', 'X_pca', 'X_scArches'
#     layers: 'cellbender_adjusted_counts', 'cellranger_raw', 'counts'

# %%
adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [ENSG00000000003, ENSG00000000005, ENSG00000000419, ENSG00000000457, ENSG00000000460, ENSG00000000938, ENSG00000000971, ENSG00000001036, ENSG00000001084, ENSG00000001167, ENSG00000001460, ENSG00000001461, ENSG00000001497, ENSG00000001561, ENSG00000001617, ENSG00000001626, ENSG00000001629, ENSG00000001630, ENSG00000001631, ENSG00000002016, ENSG00000002330, ENSG00000002549, ENSG00000002586, ENSG00000002587, ENSG00000002726, ENSG00000002745, ENSG00000002746, ENSG00000002822, ENSG00000002834, ENSG00000002919, ENSG00000002933, ENSG00000003056, ENSG00000003096, ENSG00000003137, ENSG00000003147, ENSG00000003249, ENSG00000003393, ENSG00000003400, ENSG00000003402, ENSG00000003436, ENSG00000003509, ENSG00000003756, ENSG00000003987, ENSG00000003989, ENSG00000004059, ENSG00000004139, ENSG00000004142, ENSG00000004399, ENSG00000004455, ENSG00000004468, ENSG00000004478, ENSG00000004487, ENSG00000004534, ENSG00000004660, ENSG00000004700, ENSG00000004766, ENSG00000004776, ENSG00000004777, ENSG00000004779, ENSG00000004799, ENSG00000004809, ENSG00000004838, ENSG00000004846, ENSG00000004848, ENSG00000004864, ENSG00000004866, ENSG00000004897, ENSG00000004939, ENSG00000004948, ENSG00000004961, ENSG00000004975, ENSG00000005001, ENSG00000005007, ENSG00000005020, ENSG00000005022, ENSG00000005059, ENSG00000005073, ENSG00000005075, ENSG00000005100, ENSG00000005102, ENSG00000005108, ENSG00000005156, ENSG00000005175, ENSG00000005187, ENSG00000005189, ENSG00000005194, ENSG00000005206, ENSG00000005238, ENSG00000005243, ENSG00000005249, ENSG00000005302, ENSG00000005339, ENSG00000005379, ENSG00000005381, ENSG00000005421, ENSG00000005436, ENSG00000005448, ENSG00000005469, ENSG00000005471, ENSG00000005483, ...]
#
# [37171 rows x 0 columns]

# %%
utils.add_genomic_coordinates(adata)
# Out:
# Ensembl gene IDs detected in index, merging.
# 36964 out of 37171 features (99.443114255737%) have updated information.
# AnnData object with n_obs × n_vars = 1511309 × 37171
#     obs: 'biosample_id', 'donor_id', 'disease', 'sex', 'age', 'lvef', 'cell_type_leiden0.6', 'SubCluster', 'cellbender_ncount', 'cellbender_ngenes', 'cellranger_percent_mito', 'exon_prop', 'cellbender_entropy', 'cellranger_doublet_scores', 'publication', 'donor', 'region', 'condition', 'cell_or_nuclei', 'kit_10x', 'cell_type', 'cell_state', 'Sample', 'Region_x', 'Primary.Genetic.Diagnosis', 'n_genes', 'n_counts', 'percent_mito', 'percent_ribo', 'scrublet_score_z', 'scrublet_score_log', 'solo_score', 'cell_states', 'Assigned', 'self_reported_ethnicity_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'sex_ontology_term_id', 'assay_ontology_term_id', 'organism_ontology_term_id', 'is_primary_data', 'tissue_ontology_term_id', 'development_stage_ontology_term_id', 'suspension_type', 'assay', 'organism', 'tissue', 'self_reported_ethnicity', 'development_stage', 'sangerID', 'combinedID', 'donor_type', 'region_finest', 'gender', 'facility', 'modality', 'flushed', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'scrublet_score', 'scrublet_leiden', 'cluster_scrublet_score', 'doublet_pval', 'doublet_bh_pval', 'batch_key', 'leiden_scVI', 'cell_state_HCAv1', 'cell_state_scNym', 'cell_state_scNym_confidence', 'latent_RT_efficiency', 'latent_cell_probability', 'latent_scale', '_scvi_batch', '_scvi_labels', 'clus20', 'doublet_cls', 'original_or_new', 'batch', 'scANVI_predictions', 'leiden_scArches'
#     var: 'gene_id', 'gene_name', 'gene_biotype', 'gene_seq_start', 'gene_seq_end', 'seq_name', 'seq_strand', 'seq_coord_system', 'description', 'gene_id_version', 'canonical_transcript'
#     obsm: 'X_umap', 'X_pca', 'X_scArches'
#     layers: 'cellbender_adjusted_counts', 'cellranger_raw', 'counts'

# %%
adata.var
# Out:
#                          gene_id gene_name    gene_biotype  gene_seq_start  \
# index
# ENSG00000000003  ENSG00000000003    TSPAN6  protein_coding     100627108.0
# ENSG00000000005  ENSG00000000005      TNMD  protein_coding     100584936.0
# ENSG00000000419  ENSG00000000419      DPM1  protein_coding      50934867.0
# ENSG00000000457  ENSG00000000457     SCYL3  protein_coding     169849631.0
# ENSG00000000460  ENSG00000000460  C1orf112  protein_coding     169662007.0
# ...                          ...       ...             ...             ...
# ENSG00000288380              NaN       NaN             NaN             NaN
# ENSG00000288398  ENSG00000288398                    lncRNA      16228674.0
# ENSG00000288436              NaN       NaN             NaN             NaN
# ENSG00000288459  ENSG00000288459                    lncRNA     104293678.0
# ENSG00000288460  ENSG00000288460    SMIM42  protein_coding     158127287.0
#
#                  gene_seq_end seq_name  seq_strand seq_coord_system  \
# index
# ENSG00000000003   100639991.0        X        -1.0       chromosome
# ENSG00000000005   100599885.0        X         1.0       chromosome
# ENSG00000000419    50959140.0       20        -1.0       chromosome
# ENSG00000000457   169894267.0        1        -1.0       chromosome
# ENSG00000000460   169854080.0        1         1.0       chromosome
# ...                       ...      ...         ...              ...
# ENSG00000288380           NaN      NaN         NaN              NaN
# ENSG00000288398    16231335.0        1        -1.0       chromosome
# ENSG00000288436           NaN      NaN         NaN              NaN
# ENSG00000288459   104294921.0       14         1.0       chromosome
# ENSG00000288460   158128301.0        1        -1.0       chromosome
#
#                                                        description  \
# index
# ENSG00000000003  tetraspanin 6 [Source:HGNC Symbol;Acc:HGNC:11858]
# ENSG00000000005    tenomodulin [Source:HGNC Symbol;Acc:HGNC:17757]
# ENSG00000000419  dolichyl-phosphate mannosyltransferase subunit...
# ENSG00000000457  SCY1 like pseudokinase 3 [Source:HGNC Symbol;A...
# ENSG00000000460  chromosome 1 open reading frame 112 [Source:HG...
# ...                                                            ...
# ENSG00000288380                                                NaN
# ENSG00000288398                                   novel transcript
# ENSG00000288436                                                NaN
# ENSG00000288459                                   novel transcript
# ENSG00000288460  small integral membrane protein 42 [Source:HGN...
#
#                     gene_id_version canonical_transcript
# index
# ENSG00000000003  ENSG00000000003.15      ENST00000373020
# ENSG00000000005   ENSG00000000005.6      ENST00000373031
# ENSG00000000419  ENSG00000000419.14      ENST00000371588
# ENSG00000000457  ENSG00000000457.14      ENST00000367771
# ENSG00000000460  ENSG00000000460.17      ENST00000359326
# ...                             ...                  ...
# ENSG00000288380                 NaN                  NaN
# ENSG00000288398   ENSG00000288398.1      ENST00000671994
# ENSG00000288436                 NaN                  NaN
# ENSG00000288459   ENSG00000288459.1      ENST00000672686
# ENSG00000288460   ENSG00000288460.1      ENST00000672824
#
# [37171 rows x 11 columns]

# %%
utils.rename_adata_var_index(adata,"gene_name")
# Out:
# /lustre/scratch126/cellgen/team205/jc48/miniconda3/envs/omni_env/lib/python3.11/site-packages/anndata/_core/anndata.py:887: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     ['TSPAN6', 'TNMD', 'DPM1', 'SCYL3', 'C1orf112']
#
#     Inferred to be: categorical
#
#   names = self._prep_dim_index(names, "var")
# AnnData object with n_obs × n_vars = 1511309 × 37171
#     obs: 'biosample_id', 'donor_id', 'disease', 'sex', 'age', 'lvef', 'cell_type_leiden0.6', 'SubCluster', 'cellbender_ncount', 'cellbender_ngenes', 'cellranger_percent_mito', 'exon_prop', 'cellbender_entropy', 'cellranger_doublet_scores', 'publication', 'donor', 'region', 'condition', 'cell_or_nuclei', 'kit_10x', 'cell_type', 'cell_state', 'Sample', 'Region_x', 'Primary.Genetic.Diagnosis', 'n_genes', 'n_counts', 'percent_mito', 'percent_ribo', 'scrublet_score_z', 'scrublet_score_log', 'solo_score', 'cell_states', 'Assigned', 'self_reported_ethnicity_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'sex_ontology_term_id', 'assay_ontology_term_id', 'organism_ontology_term_id', 'is_primary_data', 'tissue_ontology_term_id', 'development_stage_ontology_term_id', 'suspension_type', 'assay', 'organism', 'tissue', 'self_reported_ethnicity', 'development_stage', 'sangerID', 'combinedID', 'donor_type', 'region_finest', 'gender', 'facility', 'modality', 'flushed', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'scrublet_score', 'scrublet_leiden', 'cluster_scrublet_score', 'doublet_pval', 'doublet_bh_pval', 'batch_key', 'leiden_scVI', 'cell_state_HCAv1', 'cell_state_scNym', 'cell_state_scNym_confidence', 'latent_RT_efficiency', 'latent_cell_probability', 'latent_scale', '_scvi_batch', '_scvi_labels', 'clus20', 'doublet_cls', 'original_or_new', 'batch', 'scANVI_predictions', 'leiden_scArches'
#     var: 'index', 'gene_id', 'gene_name', 'gene_biotype', 'gene_seq_start', 'gene_seq_end', 'seq_name', 'seq_strand', 'seq_coord_system', 'description', 'gene_id_version', 'canonical_transcript'
#     obsm: 'X_umap', 'X_pca', 'X_scArches'
#     layers: 'cellbender_adjusted_counts', 'cellranger_raw', 'counts'

# %%
adata.var
# Out:
#                      index          gene_id gene_name    gene_biotype  \
# gene_name
# TSPAN6     ENSG00000000003  ENSG00000000003    TSPAN6  protein_coding
# TNMD       ENSG00000000005  ENSG00000000005      TNMD  protein_coding
# DPM1       ENSG00000000419  ENSG00000000419      DPM1  protein_coding
# SCYL3      ENSG00000000457  ENSG00000000457     SCYL3  protein_coding
# C1orf112   ENSG00000000460  ENSG00000000460  C1orf112  protein_coding
# ...                    ...              ...       ...             ...
# nan-205    ENSG00000288380              NaN       NaN             NaN
# -11567     ENSG00000288398  ENSG00000288398                    lncRNA
# nan-206    ENSG00000288436              NaN       NaN             NaN
# -11568     ENSG00000288459  ENSG00000288459                    lncRNA
# SMIM42     ENSG00000288460  ENSG00000288460    SMIM42  protein_coding
#
#            gene_seq_start  gene_seq_end seq_name  seq_strand seq_coord_system  \
# gene_name
# TSPAN6        100627108.0   100639991.0        X        -1.0       chromosome
# TNMD          100584936.0   100599885.0        X         1.0       chromosome
# DPM1           50934867.0    50959140.0       20        -1.0       chromosome
# SCYL3         169849631.0   169894267.0        1        -1.0       chromosome
# C1orf112      169662007.0   169854080.0        1         1.0       chromosome
# ...                   ...           ...      ...         ...              ...
# nan-205               NaN           NaN      NaN         NaN              NaN
# -11567         16228674.0    16231335.0        1        -1.0       chromosome
# nan-206               NaN           NaN      NaN         NaN              NaN
# -11568        104293678.0   104294921.0       14         1.0       chromosome
# SMIM42        158127287.0   158128301.0        1        -1.0       chromosome
#
#                                                  description  \
# gene_name
# TSPAN6     tetraspanin 6 [Source:HGNC Symbol;Acc:HGNC:11858]
# TNMD         tenomodulin [Source:HGNC Symbol;Acc:HGNC:17757]
# DPM1       dolichyl-phosphate mannosyltransferase subunit...
# SCYL3      SCY1 like pseudokinase 3 [Source:HGNC Symbol;A...
# C1orf112   chromosome 1 open reading frame 112 [Source:HG...
# ...                                                      ...
# nan-205                                                  NaN
# -11567                                      novel transcript
# nan-206                                                  NaN
# -11568                                      novel transcript
# SMIM42     small integral membrane protein 42 [Source:HGN...
#
#               gene_id_version canonical_transcript
# gene_name
# TSPAN6     ENSG00000000003.15      ENST00000373020
# TNMD        ENSG00000000005.6      ENST00000373031
# DPM1       ENSG00000000419.14      ENST00000371588
# SCYL3      ENSG00000000457.14      ENST00000367771
# C1orf112   ENSG00000000460.17      ENST00000359326
# ...                       ...                  ...
# nan-205                   NaN                  NaN
# -11567      ENSG00000288398.1      ENST00000671994
# nan-206                   NaN                  NaN
# -11568      ENSG00000288459.1      ENST00000672686
# SMIM42      ENSG00000288460.1      ENST00000672824
#
# [37171 rows x 12 columns]

# %%
adata.obs
# Out:
#                                                     biosample_id donor_id  \
# TTCTTCCGTTCAACGT-1-0                                LV_1622_2_nf    P1622
# CATCCACCATCTAACG-1-0                                LV_1622_2_nf    P1622
# ACCCAAACAGCTAACT-1-0                                LV_1622_2_nf    P1622
# AAGGAATCAACTGGTT-1-0                                LV_1622_2_nf    P1622
# TACCCGTAGCGTGCTC-1-0                                LV_1622_2_nf    P1622
# ...                                                          ...      ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...           NaN      NaN
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...           NaN      NaN
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...           NaN      NaN
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...           NaN      NaN
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...           NaN      NaN
#
#                                                    disease     sex   age  \
# TTCTTCCGTTCAACGT-1-0                                    NF    male  56.0
# CATCCACCATCTAACG-1-0                                    NF    male  56.0
# ACCCAAACAGCTAACT-1-0                                    NF    male  56.0
# AAGGAATCAACTGGTT-1-0                                    NF    male  56.0
# TACCCGTAGCGTGCTC-1-0                                    NF    male  56.0
# ...                                                    ...     ...   ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...     NaN  Female  47.5
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...     NaN  Female  47.5
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...     NaN  Female  47.5
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...     NaN  Female  47.5
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...     NaN  Female  47.5
#
#                                                     lvef cell_type_leiden0.6  \
# TTCTTCCGTTCAACGT-1-0                                65.0     Cardiomyocyte_I
# CATCCACCATCTAACG-1-0                                65.0     Cardiomyocyte_I
# ACCCAAACAGCTAACT-1-0                                65.0     Cardiomyocyte_I
# AAGGAATCAACTGGTT-1-0                                65.0     Cardiomyocyte_I
# TACCCGTAGCGTGCTC-1-0                                65.0     Cardiomyocyte_I
# ...                                                  ...                 ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...   NaN                 NaN
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...   NaN                 NaN
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...   NaN                 NaN
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...   NaN                 NaN
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...   NaN                 NaN
#
#                                                    SubCluster  \
# TTCTTCCGTTCAACGT-1-0                                    CM-X1
# CATCCACCATCTAACG-1-0                                 CM-HHATL
# ACCCAAACAGCTAACT-1-0                                 CM-HHATL
# AAGGAATCAACTGGTT-1-0                                    CM-X1
# TACCCGTAGCGTGCTC-1-0                                 CM-HHATL
# ...                                                       ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...        NaN
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...        NaN
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...        NaN
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...        NaN
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...        NaN
#
#                                                     cellbender_ncount  \
# TTCTTCCGTTCAACGT-1-0                                          15815.0
# CATCCACCATCTAACG-1-0                                          15546.0
# ACCCAAACAGCTAACT-1-0                                          14983.0
# AAGGAATCAACTGGTT-1-0                                          14995.0
# TACCCGTAGCGTGCTC-1-0                                          14797.0
# ...                                                               ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...                NaN
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...                NaN
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...                NaN
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...                NaN
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...                NaN
#
#                                                     cellbender_ngenes  ...  \
# TTCTTCCGTTCAACGT-1-0                                           4632.0  ...
# CATCCACCATCTAACG-1-0                                           4673.0  ...
# ACCCAAACAGCTAACT-1-0                                           4432.0  ...
# AAGGAATCAACTGGTT-1-0                                           4483.0  ...
# TACCCGTAGCGTGCTC-1-0                                           4690.0  ...
# ...                                                               ...  ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...                NaN  ...
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...                NaN  ...
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...                NaN  ...
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...                NaN  ...
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...                NaN  ...
#
#                                                     latent_cell_probability  \
# TTCTTCCGTTCAACGT-1-0                                                    NaN
# CATCCACCATCTAACG-1-0                                                    NaN
# ACCCAAACAGCTAACT-1-0                                                    NaN
# AAGGAATCAACTGGTT-1-0                                                    NaN
# TACCCGTAGCGTGCTC-1-0                                                    NaN
# ...                                                                     ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...                      NaN
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...                      NaN
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...                      NaN
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...                      NaN
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...                      NaN
#
#                                                     latent_scale  _scvi_batch  \
# TTCTTCCGTTCAACGT-1-0                                         NaN          NaN
# CATCCACCATCTAACG-1-0                                         NaN          NaN
# ACCCAAACAGCTAACT-1-0                                         NaN          NaN
# AAGGAATCAACTGGTT-1-0                                         NaN          NaN
# TACCCGTAGCGTGCTC-1-0                                         NaN          NaN
# ...                                                          ...          ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...           NaN          NaN
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...           NaN          NaN
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...           NaN          NaN
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...           NaN          NaN
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...           NaN          NaN
#
#                                                     _scvi_labels clus20  \
# TTCTTCCGTTCAACGT-1-0                                         NaN    NaN
# CATCCACCATCTAACG-1-0                                         NaN    NaN
# ACCCAAACAGCTAACT-1-0                                         NaN    NaN
# AAGGAATCAACTGGTT-1-0                                         NaN    NaN
# TACCCGTAGCGTGCTC-1-0                                         NaN    NaN
# ...                                                          ...    ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...           NaN     No
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...           NaN     No
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...           NaN     No
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...           NaN     No
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...           NaN     No
#
#                                                    doublet_cls  \
# TTCTTCCGTTCAACGT-1-0                                       NaN
# CATCCACCATCTAACG-1-0                                       NaN
# ACCCAAACAGCTAACT-1-0                                       NaN
# AAGGAATCAACTGGTT-1-0                                       NaN
# TACCCGTAGCGTGCTC-1-0                                       NaN
# ...                                                        ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...         nan
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...         nan
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...         nan
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...         nan
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...         nan
#
#                                                    original_or_new  \
# TTCTTCCGTTCAACGT-1-0                                           NaN
# CATCCACCATCTAACG-1-0                                           NaN
# ACCCAAACAGCTAACT-1-0                                           NaN
# AAGGAATCAACTGGTT-1-0                                           NaN
# TACCCGTAGCGTGCTC-1-0                                           NaN
# ...                                                            ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...        original
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...        original
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...        original
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...        original
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...        original
#
#                                                                      batch  \
# TTCTTCCGTTCAACGT-1-0                                                   NaN
# CATCCACCATCTAACG-1-0                                                   NaN
# ACCCAAACAGCTAACT-1-0                                                   NaN
# AAGGAATCAACTGGTT-1-0                                                   NaN
# TACCCGTAGCGTGCTC-1-0                                                   NaN
# ...                                                                    ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...  AH1_Nuclei_Multiome-v1
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...  AH1_Nuclei_Multiome-v1
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...  AH1_Nuclei_Multiome-v1
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...  AH1_Nuclei_Multiome-v1
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...  AH1_Nuclei_Multiome-v1
#
#                                                            scANVI_predictions  \
# TTCTTCCGTTCAACGT-1-0                                                      NaN
# CATCCACCATCTAACG-1-0                                                      NaN
# ACCCAAACAGCTAACT-1-0                                                      NaN
# AAGGAATCAACTGGTT-1-0                                                      NaN
# TACCCGTAGCGTGCTC-1-0                                                      NaN
# ...                                                                       ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...           Endothelial cell
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...                    Myeloid
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...  Ventricular Cardiomyocyte
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...                    Myeloid
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...                    Myeloid
#
#                                                    leiden_scArches
# TTCTTCCGTTCAACGT-1-0                                           NaN
# CATCCACCATCTAACG-1-0                                           NaN
# ACCCAAACAGCTAACT-1-0                                           NaN
# AAGGAATCAACTGGTT-1-0                                           NaN
# TACCCGTAGCGTGCTC-1-0                                           NaN
# ...                                                            ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...              29
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...              29
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...              13
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...              12
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...              29
#
# [1511309 rows x 84 columns]

# %%
# make a batch key
adata.obs["batch_key"]=adata.obs["donor"].astype(str)+"_"+adata.obs["kit_10x"].astype(str)+"_"+adata.obs["cell_or_nuclei"].astype(str)
adata.obs.batch_key.value_counts()
# Out:
# H5_3prime-v3_Nuclei        53434
# H6_3prime-v3_Nuclei        38907
# D11_3prime-v3_Cell         37446
# H3_3prime-v3_Nuclei        34680
# H4_3prime-v3_Nuclei        33982
#                            ...
# DO1_3prime-v3_Nuclei        1163
# IC_H03_3prime-v3_Nuclei     1066
# IC_H04_3prime-v3_Nuclei      902
# D4_3prime-v2_Cell            543
# D1_3prime-v2_Cell            166
# Name: batch_key, Length: 132, dtype: int64

# %%
adata.obs.condition.value_counts()
# Out:
# healthy    754264
# DCM        521793
# HCM        235252
# Name: condition, dtype: int64

# %%
adata.obs=adata.obs[["donor", "sex", "age", "condition", "publication", 'kit_10x', 'cell_or_nuclei',"batch_key","cell_type","cell_state"]]
adata.obs
# Out:
#                                                     donor     sex   age  \
# TTCTTCCGTTCAACGT-1-0                                P1622    male  56.0
# CATCCACCATCTAACG-1-0                                P1622    male  56.0
# ACCCAAACAGCTAACT-1-0                                P1622    male  56.0
# AAGGAATCAACTGGTT-1-0                                P1622    male  56.0
# TACCCGTAGCGTGCTC-1-0                                P1622    male  56.0
# ...                                                   ...     ...   ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...    AH1  Female  47.5
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...    AH1  Female  47.5
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...    AH1  Female  47.5
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...    AH1  Female  47.5
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...    AH1  Female  47.5
#
#                                                    condition publication  \
# TTCTTCCGTTCAACGT-1-0                                 healthy   Chaffin22
# CATCCACCATCTAACG-1-0                                 healthy   Chaffin22
# ACCCAAACAGCTAACT-1-0                                 healthy   Chaffin22
# AAGGAATCAACTGGTT-1-0                                 healthy   Chaffin22
# TACCCGTAGCGTGCTC-1-0                                 healthy   Chaffin22
# ...                                                      ...         ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...   healthy  Kanemaru22
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...   healthy  Kanemaru22
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...   healthy  Kanemaru22
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...   healthy  Kanemaru22
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...   healthy  Kanemaru22
#
#                                                         kit_10x  \
# TTCTTCCGTTCAACGT-1-0                                  3prime-v3
# CATCCACCATCTAACG-1-0                                  3prime-v3
# ACCCAAACAGCTAACT-1-0                                  3prime-v3
# AAGGAATCAACTGGTT-1-0                                  3prime-v3
# TACCCGTAGCGTGCTC-1-0                                  3prime-v3
# ...                                                         ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...  Multiome-v1
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...  Multiome-v1
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...  Multiome-v1
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...  Multiome-v1
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...  Multiome-v1
#
#                                                    cell_or_nuclei  \
# TTCTTCCGTTCAACGT-1-0                                       Nuclei
# CATCCACCATCTAACG-1-0                                       Nuclei
# ACCCAAACAGCTAACT-1-0                                       Nuclei
# AAGGAATCAACTGGTT-1-0                                       Nuclei
# TACCCGTAGCGTGCTC-1-0                                       Nuclei
# ...                                                           ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...         Nuclei
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...         Nuclei
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...         Nuclei
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...         Nuclei
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...         Nuclei
#
#                                                                  batch_key  \
# TTCTTCCGTTCAACGT-1-0                                P1622_3prime-v3_Nuclei
# CATCCACCATCTAACG-1-0                                P1622_3prime-v3_Nuclei
# ACCCAAACAGCTAACT-1-0                                P1622_3prime-v3_Nuclei
# AAGGAATCAACTGGTT-1-0                                P1622_3prime-v3_Nuclei
# TACCCGTAGCGTGCTC-1-0                                P1622_3prime-v3_Nuclei
# ...                                                                    ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...  AH1_Multiome-v1_Nuclei
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...  AH1_Multiome-v1_Nuclei
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...  AH1_Multiome-v1_Nuclei
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...  AH1_Multiome-v1_Nuclei
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...  AH1_Multiome-v1_Nuclei
#
#                                                                     cell_type  \
# TTCTTCCGTTCAACGT-1-0                                          Cardiomyocyte_I
# CATCCACCATCTAACG-1-0                                          Cardiomyocyte_I
# ACCCAAACAGCTAACT-1-0                                          Cardiomyocyte_I
# AAGGAATCAACTGGTT-1-0                                          Cardiomyocyte_I
# TACCCGTAGCGTGCTC-1-0                                          Cardiomyocyte_I
# ...                                                                       ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...                 Fibroblast
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...  Ventricular Cardiomyocyte
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...  Ventricular Cardiomyocyte
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...                    Myeloid
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...                    Myeloid
#
#                                                       cell_state
# TTCTTCCGTTCAACGT-1-0                                       CM-X1
# CATCCACCATCTAACG-1-0                                    CM-HHATL
# ACCCAAACAGCTAACT-1-0                                    CM-HHATL
# AAGGAATCAACTGGTT-1-0                                       CM-X1
# TACCCGTAGCGTGCTC-1-0                                    CM-HHATL
# ...                                                          ...
# HCAHeartST11064577_HCAHeartST11023242_CAATGACTC...  unclassified
# HCAHeartST11064577_HCAHeartST11023242_AGCTACGTC...          vCM1
# HCAHeartST11064577_HCAHeartST11023242_CGTCATTGT...          vCM4
# HCAHeartST11064577_HCAHeartST11023242_TCACTGACA...  unclassified
# HCAHeartST11064577_HCAHeartST11023242_CGAATATGT...  unclassified
#
# [1511309 rows x 10 columns]

# %%
adata.obs.age.value_counts()
# Out:
# 45.0    174759
# 55.0    152717
# 65.0    109549
# 62.5     94712
# 52.5     68309
# 63.0     65888
# 54.0     64093
# 47.5     58876
# 51.0     58029
# 67.5     57134
# 46.0     52740
# 25.0     44449
# 75.0     41436
# 35.0     41249
# 58.0     40068
# 49.0     37475
# 57.5     35996
# 29.0     28641
# 15.0     25865
# 42.0     23984
# 60.0     20536
# 42.5     19954
# 41.0     19513
# 62.0     19384
# 64.0     17986
# 56.0     15733
# 40.0     15378
# 72.5     14693
# 5.0      14613
# 59.0     13550
# 61.0     12009
# 72.0     11638
# 47.0     11076
# 69.0     10638
# 66.0      9361
# 33.0      9278
# Name: age, dtype: int64

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1511309 × 37171
#     obs: 'donor', 'sex', 'age', 'condition', 'publication', 'kit_10x', 'cell_or_nuclei', 'batch_key', 'cell_type', 'cell_state'
#     var: 'index', 'gene_id', 'gene_name', 'gene_biotype', 'gene_seq_start', 'gene_seq_end', 'seq_name', 'seq_strand', 'seq_coord_system', 'description', 'gene_id_version', 'canonical_transcript'
#     obsm: 'X_umap', 'X_pca', 'X_scArches'
#     layers: 'cellbender_adjusted_counts', 'cellranger_raw', 'counts'

# %%
del adata.obsm["X_umap"]

# %%
del adata.obsm["X_pca"]

# %%
del adata.obsm["X_scArches"]

# %%
del adata.layers["cellbender_adjusted_counts"]

# %%
del adata.layers["cellranger_raw"]

# %%
del adata.layers["counts"]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1511309 × 37171
#     obs: 'donor', 'sex', 'age', 'condition', 'publication', 'kit_10x', 'cell_or_nuclei', 'batch_key', 'cell_type', 'cell_state'
#     var: 'index', 'gene_id', 'gene_name', 'gene_biotype', 'gene_seq_start', 'gene_seq_end', 'seq_name', 'seq_strand', 'seq_coord_system', 'description', 'gene_id_version', 'canonical_transcript'

# %%
adata.write("/nfs/team205/jc48/ForHana/HeartData.h5ad")
